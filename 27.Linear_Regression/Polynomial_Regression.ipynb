# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# outliers
x=6*np.random.rand(100,1)-3
x
# Out:
# array([[-1.20217287],
#        [-2.8924576 ],
#        [ 1.85900973],
#        [ 2.18595114],
#        [-0.89799541],
#        [ 0.02823898],
#        [-0.69833836],
#        [ 0.92370353],
#        [ 2.58183139],
#        [-0.9687182 ],
#        [ 1.5882411 ],
#        [ 0.82472628],
#        [ 1.58941524],
#        [ 0.45240485],
#        [-2.75441683],
#        [ 2.25184467],
#        [ 1.96766503],
#        [-1.39224957],
#        [-2.286811  ],
#        [ 2.0120903 ],
#        [ 2.01254601],
#        [-1.54933463],
#        [ 2.15090753],
#        [-2.07753985],
#        [ 2.42447427],
#        [-1.70479641],
#        [ 2.80234324],
#        [-0.26821013],
#        [ 0.33425434],
#        [ 2.8965036 ],
#        [-1.4270645 ],
#        [ 2.83391782],
#        [-0.08628582],
#        [ 0.89114951],
#        [-2.43749238],
#        [ 2.18733842],
#        [-2.23742074],
#        [-0.30288622],
#        [ 1.03479321],
#        [-0.91836726],
#        [ 1.05185105],
# ...

# %%
#Quadratic eqn : 0.5x^2+1.5x+ outliers
y=0.5*x**2 + 1.5*x +np.random.randn(100,1)
y
# Out:
# array([[-2.95651617],
#        [ 0.10748586],
#        [ 5.73553773],
#        [ 4.89898172],
#        [-1.34557678],
#        [ 0.06537771],
#        [ 0.09264059],
#        [ 1.4655166 ],
#        [ 7.18368399],
#        [-1.62562425],
#        [ 3.79807956],
#        [ 1.28715116],
#        [ 3.1604696 ],
#        [ 1.80385381],
#        [-0.19077978],
#        [ 5.80331772],
#        [ 6.30399599],
#        [-0.76987692],
#        [-2.23338327],
#        [ 5.50489459],
#        [ 4.51626611],
#        [ 0.30855119],
#        [ 5.61650794],
#        [ 0.64720379],
#        [ 5.34985838],
#        [-2.10838074],
#        [ 8.91171172],
#        [ 0.54356442],
#        [ 0.13656412],
#        [ 8.06398761],
#        [-2.57252068],
#        [ 7.14836392],
#        [ 1.218368  ],
#        [ 2.18499944],
#        [-0.62251559],
#        [ 7.34675246],
#        [-2.09902263],
#        [-2.06701808],
#        [ 2.77345356],
#        [ 0.31586249],
#        [ 1.23821687],
# ...

# %%
plt.plot(x,y,"green")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(x,y,color='green')
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[ 1.53393788],
#        [ 2.84018463],
#        [ 2.80234324],
#        [ 2.15795287],
#        [-0.27284583],
#        [ 2.25184467],
#        [ 1.05185105],
#        [ 1.01492529],
#        [-0.9687182 ],
#        [-2.77945475],
#        [ 0.82472628],
#        [-2.99401539],
#        [ 1.50635279],
#        [ 0.33425434],
#        [ 2.16518537],
#        [ 0.02823898],
#        [-2.49826917],
#        [ 2.62813918],
#        [ 2.18733842],
#        [ 1.96766503],
#        [ 0.68572204],
#        [-2.43749238],
#        [ 0.92370353],
#        [ 0.59020174],
#        [-0.26821013],
#        [ 2.0120903 ],
#        [-2.50102974],
#        [-1.70479641],
#        [ 2.13594162],
#        [ 0.45240485],
#        [ 2.42447427],
#        [ 2.18595114],
#        [-1.39224957],
#        [ 1.03479321],
#        [ 2.58183139],
#        [ 0.30339755],
#        [-0.69833836],
#        [ 1.65946271],
#        [-2.23742074],
#        [ 2.51018366],
#        [-1.25065672],
# ...

# %%
x_test
# Out:
# array([[ 2.30258137],
#        [-2.83777808],
#        [ 0.47413773],
#        [-1.16954397],
#        [ 0.05973797],
#        [-0.91836726],
#        [ 2.15090753],
#        [ 1.96250956],
#        [ 1.5882411 ],
#        [-1.20217287],
#        [-2.286811  ],
#        [-1.4270645 ],
#        [-1.69044324],
#        [ 0.89114951],
#        [-1.29227567],
#        [-0.89799541],
#        [-1.32800961],
#        [-1.79715072],
#        [ 1.58941524],
#        [ 2.83391782]])

# %%
y_train
# Out:
# array([[ 3.87592447],
#        [ 8.88670156],
#        [ 8.91171172],
#        [ 6.82896474],
#        [-0.38393958],
#        [ 5.80331772],
#        [ 1.23821687],
#        [ 1.01130537],
#        [-1.62562425],
#        [-1.3492327 ],
#        [ 1.28715116],
#        [ 3.68658279],
#        [ 4.4608012 ],
#        [ 0.13656412],
#        [ 5.56259931],
#        [ 0.06537771],
#        [ 0.45391345],
#        [ 6.92349709],
#        [ 7.34675246],
#        [ 6.30399599],
#        [ 1.25311359],
#        [-0.62251559],
#        [ 1.4655166 ],
#        [ 1.01485087],
#        [ 0.54356442],
#        [ 5.50489459],
#        [-0.83812642],
#        [-2.10838074],
#        [ 4.144614  ],
#        [ 1.80385381],
#        [ 5.34985838],
#        [ 4.89898172],
#        [-0.76987692],
#        [ 2.77345356],
#        [ 7.18368399],
#        [ 1.53421277],
#        [ 0.09264059],
#        [ 5.38598124],
#        [-2.09902263],
#        [ 7.11763903],
#        [-0.52511126],
# ...

# %%
y_test
# Out:
# array([[ 7.82905499],
#        [-0.45032345],
#        [-0.60390433],
#        [-0.62789949],
#        [-0.87874348],
#        [ 0.31586249],
#        [ 5.61650794],
#        [ 3.84059002],
#        [ 3.79807956],
#        [-2.95651617],
#        [-2.23338327],
#        [-2.57252068],
#        [-3.2437675 ],
#        [ 2.18499944],
#        [-0.99178236],
#        [-1.34557678],
#        [-0.72589908],
#        [-2.62563568],
#        [ 3.1604696 ],
#        [ 7.14836392]])

# %%
plt.plot(x_test,y_test)

# %%
plt.plot(x_train,y_train)

# %%
#lets implement simple linear regression
from sklearn.linear_model import LinearRegression
LR1=LinearRegression()

# %%
LR1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
sscore=r2_score(y_test,LR1.predict(x_test))
print(sscore)
# Out:
# 0.6971535578278231

# %%
#visualizing the model
plt.plot(x_train,LR1.predict(x_train),color='red')
plt.scatter(x_train,y_train)
plt.xlabel("x-train")
plt.ylabel("y-train")
# Out:
# Text(0, 0.5, 'y-train')

# %%
#Lets apply polynomial transformation

from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)

x_train_poly=poly.fit_transform(x_train)
y_train_poly=poly.transform(y_train)

x_test_poly=poly.fit_transform(x_test)
y_test_poly=poly.transform(y_test)


print(x_train_poly,"\n\n",y_train_poly)

print(x_test_poly,"\n\n",y_test_poly)
# Out:
# [[ 1.00000000e+00  1.53393788e+00  2.35296543e+00]
#  [ 1.00000000e+00  2.84018463e+00  8.06664871e+00]
#  [ 1.00000000e+00  2.80234324e+00  7.85312764e+00]
#  [ 1.00000000e+00  2.15795287e+00  4.65676057e+00]
#  [ 1.00000000e+00 -2.72845832e-01  7.44448478e-02]
#  [ 1.00000000e+00  2.25184467e+00  5.07080443e+00]
#  [ 1.00000000e+00  1.05185105e+00  1.10639062e+00]
#  [ 1.00000000e+00  1.01492529e+00  1.03007335e+00]
#  [ 1.00000000e+00 -9.68718197e-01  9.38414945e-01]
#  [ 1.00000000e+00 -2.77945475e+00  7.72536870e+00]
#  [ 1.00000000e+00  8.24726280e-01  6.80173437e-01]
#  [ 1.00000000e+00 -2.99401539e+00  8.96412816e+00]
#  [ 1.00000000e+00  1.50635279e+00  2.26909872e+00]
#  [ 1.00000000e+00  3.34254341e-01  1.11725965e-01]
#  [ 1.00000000e+00  2.16518537e+00  4.68802767e+00]
#  [ 1.00000000e+00  2.82389764e-02  7.97439788e-04]
#  [ 1.00000000e+00 -2.49826917e+00  6.24134885e+00]
#  [ 1.00000000e+00  2.62813918e+00  6.90711553e+00]
# ...

# %%
#lets implement Polynomial regression
from sklearn.linear_model import LinearRegression
LR2=LinearRegression()
LR2.fit(x_train_poly,y_train)
y_new_pred=LR2.predict(x_test_poly)

from sklearn.metrics import r2_score
score_new=r2_score(y_test,y_new_pred)

print(score_new)
# Out:
# 0.8601992407444005

# %%
print(sscore)
# Out:
# 0.6971535578278231

# %%
LR2.coef_
# Out:
# array([[0.        , 1.40227714, 0.55222005]])

# %%
plt.scatter(x_train,LR2.predict(x_train_poly))
plt.scatter(x_train,y_train)

# %%
#for degree 3
poly1=PolynomialFeatures(degree=3,include_bias=True)

x_train_poly1=poly1.fit_transform(x_train)
y_train_poly1=poly1.transform(y_train)

x_test_poly1=poly1.fit_transform(x_test)
y_test_poly1=poly1.transform(y_test)

# %%
#lets implement Polynomial regression
from sklearn.linear_model import LinearRegression
LR3=LinearRegression()
LR3.fit(x_train_poly1,y_train)
y_new_pred1=LR3.predict(x_test_poly1)

from sklearn.metrics import r2_score
score_new1=r2_score(y_test,y_new_pred1)

print(score_new1)
# Out:
# 0.8679098928939921

# %%
plt.scatter(x_train,LR3.predict(x_train_poly1))
plt.scatter(x_train,y_train)

# %%
#prediction of new data
x_new=np.linspace(-3,3,200).reshape(200,1)
xnew_pol=poly1.transform(x_new)

# %%
y_new=LR3.predict(xnew_pol)
plt.plot(x_new,y_new,'r-',linewidth=2,label='predictions')
plt.plot(x_train,y_train,'b.',label='Training Points')
plt.plot(x_test,y_test,'g.',label='Testing Points')
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
#pipeline in polynomial
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    x_new= np.linspace(-3,3,200).reshape(200,1)

    poly_features=PolynomialFeatures(degree=degree,include_bias=True)
    line_reg=LinearRegression()
    poly_regression=Pipeline([
        ("poly_features",poly_features),
        ("line_reg",line_reg)
    ])

    poly_regression.fit(x_train,y_train)
    y_pred_new=poly_regression.predict(x_new)

    #plotting prediction line
    plt.plot(x_new,y_pred_new,'r',label="Degree"+str(degree),linewidth=3)
    plt.plot(x_train,y_train,'b.',linewidth=3)
    plt.plot(x_test,y_test,'g.',linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axis([-4,4,0,10])
    plt.show()

# %%
poly_regression(4)
